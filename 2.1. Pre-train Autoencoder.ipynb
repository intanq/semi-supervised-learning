# %% [markdown]
# # SSL dengan Autoencoder

# %% [markdown]
# ## Import Modules

# %%
import os
import time as timer

import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader

import numpy as np

from sklearn.preprocessing import MinMaxScaler

from torchvision import datasets
import torchvision.transforms as T

import visualization_utils as vu
import train_utils as tu
import autoencoder as ae

# %% [markdown]
# ## Define Constants

# %%
DATA_DIR = './data'
MODEL_DIR = './models'

EPOCHS = 100
BATCH_SIZE = 128
LEARNING_RATE = 1e-3
dz = 300

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ## Data Preparation

# %%
training_data = datasets.MNIST(
    root=DATA_DIR, 
    train=True, 
    download=True,
    transform=T.ToTensor(), #convert to Tensor and normalize to (0, 1)
)

test_data = datasets.MNIST(
    root=DATA_DIR,
    train=False,
    download=True,
    transform=T.ToTensor(), #convert to Tensor and normalize to (0, 1)
)

# %%
"""Create data loaders"""
train_dl = DataLoader(training_data, batch_size=BATCH_SIZE)
test_dl = DataLoader(test_data, batch_size=BATCH_SIZE)

# %%
X_train = training_data.data
X_test = test_data.data

[n, dx1, dx2] = X_train.shape
n, dx1, dx2
# Out:
# (60000, 28, 28)

# %% [markdown]
# ### Reshape

# %%
X_train_reshaped = torch.reshape(X_train, (-1, dx1*dx2)).float()
X_test_reshaped = torch.reshape(X_test, (-1, dx1*dx2)).float()

X_train_reshaped.shape, X_test_reshaped.shape
# Out:
# (torch.Size([60000, 784]), torch.Size([10000, 784]))

# %% [markdown]
# ### Scale using MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range=(0,1))
X_train_scaled = scaler.fit_transform(X_train_reshaped)
X_train_scaled.shape
# Out:
# (60000, 784)

# %% [markdown]
# ### Visualize Scaled X train

# %%
viz = np.reshape(X_train_scaled, (-1, dx1, dx2))
grid = vu.set_grid(viz, num_cells=48)
vu.show(grid)

# %% [markdown]
# ## Train Autoencoder

# %%
print(f"Device: {DEVICE}")
# Out:
# Device: cuda

# %%
model = ae.MLPAutoEnc(d_in=dx1*dx2, d_z=dz, d_h=512).to(DEVICE)
print(model)

# Persistent file to store the model
model_path = os.path.join(MODEL_DIR, 'uns_ae_mnist.pth')
# Out:
# MLPAutoEnc(
#   (encoder): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=300, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=300, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=784, bias=True)
#     (3): Sigmoid()
#   )
# )

# %%
"""Define loss function"""
loss_fn = nn.MSELoss()

"""Define optimizer"""
optimizer = optim.Adam(
    model.parameters(), 
    lr=LEARNING_RATE
)

# %%
"""Train the Autoencoder"""

for t in range(EPOCHS):
    print(f"Epoch {t+1} out of {EPOCHS}\n ------------")
    
    start = timer.time()
    tu.train_uns(train_dl, model, loss_fn, optimizer)
    elapsed_time = timer.time() - start # this timing method ONLY works for CPU computation, not for GPU/cuda calls
    print(f" > Training time: {elapsed_time:>.2f} seconds")
    
    test_loss = tu.test_uns(test_dl, model, loss_fn)
    print(f" > Test reconstruction loss: {test_loss:>.2f}")
    
    # Save model
    torch.save(model.state_dict(), model_path)
    print(f"Model {model_path} stored!")
    
print("Done!")
# Out:
# Epoch 1 out of 100
#  ------------
# Loss: 0.231258 [    0]/60000
# Loss: 0.039341 [12800]/60000
# Loss: 0.025731 [25600]/60000
# Loss: 0.017594 [38400]/60000
# Loss: 0.013660 [51200]/60000
#  > Training time: 6.40 seconds
#  > Test reconstruction loss: 0.01
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 2 out of 100
#  ------------
# Loss: 0.013407 [    0]/60000
# Loss: 0.011777 [12800]/60000
# Loss: 0.009834 [25600]/60000
# Loss: 0.008463 [38400]/60000
# Loss: 0.007522 [51200]/60000
#  > Training time: 5.04 seconds
#  > Test reconstruction loss: 0.01
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 3 out of 100
#  ------------
# Loss: 0.007727 [    0]/60000
# Loss: 0.007504 [12800]/60000
# Loss: 0.006480 [25600]/60000
# Loss: 0.005765 [38400]/60000
# Loss: 0.005468 [51200]/60000
#  > Training time: 4.83 seconds
#  > Test reconstruction loss: 0.01
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 4 out of 100
#  ------------
# Loss: 0.005698 [    0]/60000
# Loss: 0.005680 [12800]/60000
# Loss: 0.005036 [25600]/60000
# Loss: 0.004505 [38400]/60000
# Loss: 0.004492 [51200]/60000
#  > Training time: 4.79 seconds
#  > Test reconstruction loss: 0.01
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 5 out of 100
#  ------------
# Loss: 0.004836 [    0]/60000
# Loss: 0.004595 [12800]/60000
# Loss: 0.004275 [25600]/60000
# Loss: 0.003772 [38400]/60000
# Loss: 0.003810 [51200]/60000
#  > Training time: 4.76 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 6 out of 100
#  ------------
# Loss: 0.004112 [    0]/60000
# Loss: 0.003963 [12800]/60000
# Loss: 0.003707 [25600]/60000
# Loss: 0.003303 [38400]/60000
# Loss: 0.003275 [51200]/60000
#  > Training time: 4.87 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 7 out of 100
#  ------------
# Loss: 0.003618 [    0]/60000
# Loss: 0.003568 [12800]/60000
# Loss: 0.003331 [25600]/60000
# Loss: 0.002901 [38400]/60000
# Loss: 0.002948 [51200]/60000
#  > Training time: 4.94 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 8 out of 100
#  ------------
# Loss: 0.003355 [    0]/60000
# Loss: 0.003171 [12800]/60000
# Loss: 0.002956 [25600]/60000
# Loss: 0.002593 [38400]/60000
# Loss: 0.002685 [51200]/60000
#  > Training time: 4.79 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 9 out of 100
#  ------------
# Loss: 0.003119 [    0]/60000
# Loss: 0.002880 [12800]/60000
# Loss: 0.002739 [25600]/60000
# Loss: 0.002375 [38400]/60000
# Loss: 0.002451 [51200]/60000
#  > Training time: 4.80 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 10 out of 100
#  ------------
# Loss: 0.002920 [    0]/60000
# Loss: 0.002642 [12800]/60000
# Loss: 0.002567 [25600]/60000
# Loss: 0.002208 [38400]/60000
# Loss: 0.002234 [51200]/60000
#  > Training time: 4.86 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 11 out of 100
#  ------------
# Loss: 0.002777 [    0]/60000
# Loss: 0.002436 [12800]/60000
# Loss: 0.002403 [25600]/60000
# Loss: 0.002065 [38400]/60000
# Loss: 0.002105 [51200]/60000
#  > Training time: 4.82 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 12 out of 100
#  ------------
# Loss: 0.002601 [    0]/60000
# Loss: 0.002278 [12800]/60000
# Loss: 0.002298 [25600]/60000
# Loss: 0.001944 [38400]/60000
# Loss: 0.001978 [51200]/60000
#  > Training time: 4.88 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 13 out of 100
#  ------------
# Loss: 0.002493 [    0]/60000
# Loss: 0.002149 [12800]/60000
# Loss: 0.002151 [25600]/60000
# Loss: 0.001855 [38400]/60000
# Loss: 0.001888 [51200]/60000
#  > Training time: 4.89 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 14 out of 100
#  ------------
# Loss: 0.002483 [    0]/60000
# Loss: 0.002048 [12800]/60000
# Loss: 0.002057 [25600]/60000
# Loss: 0.001792 [38400]/60000
# Loss: 0.001815 [51200]/60000
#  > Training time: 4.83 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 15 out of 100
#  ------------
# Loss: 0.003074 [    0]/60000
# Loss: 0.002011 [12800]/60000
# Loss: 0.002014 [25600]/60000
# Loss: 0.001752 [38400]/60000
# Loss: 0.001741 [51200]/60000
#  > Training time: 4.87 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 16 out of 100
#  ------------
# Loss: 0.002385 [    0]/60000
# Loss: 0.001885 [12800]/60000
# Loss: 0.001882 [25600]/60000
# Loss: 0.001653 [38400]/60000
# Loss: 0.001671 [51200]/60000
#  > Training time: 4.86 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 17 out of 100
#  ------------
# Loss: 0.002089 [    0]/60000
# Loss: 0.001793 [12800]/60000
# Loss: 0.001797 [25600]/60000
# Loss: 0.001585 [38400]/60000
# Loss: 0.001614 [51200]/60000
#  > Training time: 4.79 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 18 out of 100
#  ------------
# Loss: 0.002079 [    0]/60000
# Loss: 0.001720 [12800]/60000
# Loss: 0.001752 [25600]/60000
# Loss: 0.001527 [38400]/60000
# Loss: 0.001586 [51200]/60000
#  > Training time: 4.81 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 19 out of 100
#  ------------
# Loss: 0.001995 [    0]/60000
# Loss: 0.001660 [12800]/60000
# Loss: 0.001712 [25600]/60000
# Loss: 0.001491 [38400]/60000
# Loss: 0.001548 [51200]/60000
#  > Training time: 4.86 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 20 out of 100
#  ------------
# Loss: 0.002176 [    0]/60000
# Loss: 0.001633 [12800]/60000
# Loss: 0.001660 [25600]/60000
# Loss: 0.001461 [38400]/60000
# Loss: 0.001501 [51200]/60000
#  > Training time: 4.84 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 21 out of 100
#  ------------
# Loss: 0.002041 [    0]/60000
# Loss: 0.001604 [12800]/60000
# Loss: 0.001613 [25600]/60000
# Loss: 0.001442 [38400]/60000
# Loss: 0.001471 [51200]/60000
#  > Training time: 4.88 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 22 out of 100
#  ------------
# Loss: 0.001958 [    0]/60000
# Loss: 0.001581 [12800]/60000
# Loss: 0.001563 [25600]/60000
# Loss: 0.001382 [38400]/60000
# Loss: 0.001452 [51200]/60000
#  > Training time: 5.07 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 23 out of 100
#  ------------
# Loss: 0.002136 [    0]/60000
# Loss: 0.001568 [12800]/60000
# Loss: 0.001534 [25600]/60000
# Loss: 0.001329 [38400]/60000
# Loss: 0.001397 [51200]/60000
#  > Training time: 4.84 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 24 out of 100
#  ------------
# Loss: 0.001899 [    0]/60000
# Loss: 0.001516 [12800]/60000
# Loss: 0.001459 [25600]/60000
# Loss: 0.001300 [38400]/60000
# Loss: 0.001359 [51200]/60000
#  > Training time: 4.89 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 25 out of 100
#  ------------
# Loss: 0.001743 [    0]/60000
# Loss: 0.001455 [12800]/60000
# Loss: 0.001423 [25600]/60000
# Loss: 0.001262 [38400]/60000
# Loss: 0.001291 [51200]/60000
#  > Training time: 4.80 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 26 out of 100
#  ------------
# Loss: 0.001857 [    0]/60000
# Loss: 0.001434 [12800]/60000
# Loss: 0.001395 [25600]/60000
# Loss: 0.001236 [38400]/60000
# Loss: 0.001257 [51200]/60000
#  > Training time: 4.79 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 27 out of 100
#  ------------
# Loss: 0.001791 [    0]/60000
# Loss: 0.001400 [12800]/60000
# Loss: 0.001349 [25600]/60000
# Loss: 0.001237 [38400]/60000
# Loss: 0.001223 [51200]/60000
#  > Training time: 4.71 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 28 out of 100
#  ------------
# Loss: 0.001708 [    0]/60000
# Loss: 0.001373 [12800]/60000
# Loss: 0.001339 [25600]/60000
# Loss: 0.001205 [38400]/60000
# Loss: 0.001209 [51200]/60000
#  > Training time: 4.81 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 29 out of 100
#  ------------
# Loss: 0.001678 [    0]/60000
# Loss: 0.001339 [12800]/60000
# Loss: 0.001334 [25600]/60000
# Loss: 0.001195 [38400]/60000
# Loss: 0.001181 [51200]/60000
#  > Training time: 4.72 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 30 out of 100
#  ------------
# Loss: 0.001739 [    0]/60000
# Loss: 0.001354 [12800]/60000
# Loss: 0.001327 [25600]/60000
# Loss: 0.001223 [38400]/60000
# Loss: 0.001205 [51200]/60000
#  > Training time: 4.66 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 31 out of 100
#  ------------
# Loss: 0.001635 [    0]/60000
# Loss: 0.001348 [12800]/60000
# Loss: 0.001310 [25600]/60000
# Loss: 0.001128 [38400]/60000
# Loss: 0.001191 [51200]/60000
#  > Training time: 4.74 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 32 out of 100
#  ------------
# Loss: 0.001651 [    0]/60000
# Loss: 0.001313 [12800]/60000
# Loss: 0.001289 [25600]/60000
# Loss: 0.001133 [38400]/60000
# Loss: 0.001173 [51200]/60000
#  > Training time: 4.81 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 33 out of 100
#  ------------
# Loss: 0.001732 [    0]/60000
# Loss: 0.001305 [12800]/60000
# Loss: 0.001281 [25600]/60000
# Loss: 0.001110 [38400]/60000
# Loss: 0.001122 [51200]/60000
#  > Training time: 4.97 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 34 out of 100
#  ------------
# Loss: 0.001432 [    0]/60000
# Loss: 0.001236 [12800]/60000
# Loss: 0.001216 [25600]/60000
# Loss: 0.001069 [38400]/60000
# Loss: 0.001096 [51200]/60000
#  > Training time: 4.92 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 35 out of 100
#  ------------
# Loss: 0.001383 [    0]/60000
# Loss: 0.001193 [12800]/60000
# Loss: 0.001171 [25600]/60000
# Loss: 0.001042 [38400]/60000
# Loss: 0.001062 [51200]/60000
#  > Training time: 4.84 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 36 out of 100
#  ------------
# Loss: 0.001327 [    0]/60000
# Loss: 0.001194 [12800]/60000
# Loss: 0.001161 [25600]/60000
# Loss: 0.001025 [38400]/60000
# Loss: 0.001043 [51200]/60000
#  > Training time: 4.85 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 37 out of 100
#  ------------
# Loss: 0.001321 [    0]/60000
# Loss: 0.001175 [12800]/60000
# Loss: 0.001144 [25600]/60000
# Loss: 0.001003 [38400]/60000
# Loss: 0.001055 [51200]/60000
#  > Training time: 4.86 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 38 out of 100
#  ------------
# Loss: 0.001284 [    0]/60000
# Loss: 0.001162 [12800]/60000
# Loss: 0.001133 [25600]/60000
# Loss: 0.001026 [38400]/60000
# Loss: 0.001060 [51200]/60000
#  > Training time: 4.91 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 39 out of 100
#  ------------
# Loss: 0.001396 [    0]/60000
# Loss: 0.001172 [12800]/60000
# Loss: 0.001128 [25600]/60000
# Loss: 0.001048 [38400]/60000
# Loss: 0.001032 [51200]/60000
#  > Training time: 5.28 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 40 out of 100
#  ------------
# Loss: 0.001240 [    0]/60000
# Loss: 0.001137 [12800]/60000
# Loss: 0.001136 [25600]/60000
# Loss: 0.000991 [38400]/60000
# Loss: 0.001007 [51200]/60000
#  > Training time: 4.96 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 41 out of 100
#  ------------
# Loss: 0.001226 [    0]/60000
# Loss: 0.001136 [12800]/60000
# Loss: 0.001108 [25600]/60000
# Loss: 0.001008 [38400]/60000
# Loss: 0.000993 [51200]/60000
#  > Training time: 5.04 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 42 out of 100
#  ------------
# Loss: 0.001247 [    0]/60000
# Loss: 0.001110 [12800]/60000
# Loss: 0.001083 [25600]/60000
# Loss: 0.001021 [38400]/60000
# Loss: 0.000978 [51200]/60000
#  > Training time: 4.97 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 43 out of 100
#  ------------
# Loss: 0.001286 [    0]/60000
# Loss: 0.001099 [12800]/60000
# Loss: 0.001059 [25600]/60000
# Loss: 0.001005 [38400]/60000
# Loss: 0.000965 [51200]/60000
#  > Training time: 5.04 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 44 out of 100
#  ------------
# Loss: 0.001179 [    0]/60000
# Loss: 0.001080 [12800]/60000
# Loss: 0.001068 [25600]/60000
# Loss: 0.000999 [38400]/60000
# Loss: 0.000945 [51200]/60000
#  > Training time: 4.98 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 45 out of 100
#  ------------
# Loss: 0.001151 [    0]/60000
# Loss: 0.001056 [12800]/60000
# Loss: 0.001071 [25600]/60000
# Loss: 0.001000 [38400]/60000
# Loss: 0.000951 [51200]/60000
#  > Training time: 4.98 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 46 out of 100
#  ------------
# Loss: 0.001257 [    0]/60000
# Loss: 0.001048 [12800]/60000
# Loss: 0.001050 [25600]/60000
# Loss: 0.000981 [38400]/60000
# Loss: 0.000949 [51200]/60000
#  > Training time: 4.92 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 47 out of 100
#  ------------
# Loss: 0.001348 [    0]/60000
# Loss: 0.001047 [12800]/60000
# Loss: 0.001040 [25600]/60000
# Loss: 0.000938 [38400]/60000
# Loss: 0.000947 [51200]/60000
#  > Training time: 4.89 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 48 out of 100
#  ------------
# Loss: 0.001226 [    0]/60000
# Loss: 0.001036 [12800]/60000
# Loss: 0.001031 [25600]/60000
# Loss: 0.000898 [38400]/60000
# Loss: 0.000919 [51200]/60000
#  > Training time: 4.86 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 49 out of 100
#  ------------
# Loss: 0.001139 [    0]/60000
# Loss: 0.001005 [12800]/60000
# Loss: 0.001012 [25600]/60000
# Loss: 0.000907 [38400]/60000
# Loss: 0.000902 [51200]/60000
#  > Training time: 5.03 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 50 out of 100
#  ------------
# Loss: 0.001086 [    0]/60000
# Loss: 0.001010 [12800]/60000
# Loss: 0.001000 [25600]/60000
# Loss: 0.000899 [38400]/60000
# Loss: 0.000910 [51200]/60000
#  > Training time: 4.84 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 51 out of 100
#  ------------
# Loss: 0.001080 [    0]/60000
# Loss: 0.001013 [12800]/60000
# Loss: 0.001016 [25600]/60000
# Loss: 0.000891 [38400]/60000
# Loss: 0.000912 [51200]/60000
#  > Training time: 4.82 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 52 out of 100
#  ------------
# Loss: 0.001135 [    0]/60000
# Loss: 0.000998 [12800]/60000
# Loss: 0.001036 [25600]/60000
# Loss: 0.000893 [38400]/60000
# Loss: 0.000884 [51200]/60000
#  > Training time: 4.90 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 53 out of 100
#  ------------
# Loss: 0.001118 [    0]/60000
# Loss: 0.000987 [12800]/60000
# Loss: 0.000991 [25600]/60000
# Loss: 0.000889 [38400]/60000
# Loss: 0.000882 [51200]/60000
#  > Training time: 4.94 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 54 out of 100
#  ------------
# Loss: 0.001043 [    0]/60000
# Loss: 0.000963 [12800]/60000
# Loss: 0.000965 [25600]/60000
# Loss: 0.000863 [38400]/60000
# Loss: 0.000861 [51200]/60000
#  > Training time: 4.98 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 55 out of 100
#  ------------
# Loss: 0.001029 [    0]/60000
# Loss: 0.000949 [12800]/60000
# Loss: 0.000944 [25600]/60000
# Loss: 0.000845 [38400]/60000
# Loss: 0.000874 [51200]/60000
#  > Training time: 4.76 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 56 out of 100
#  ------------
# Loss: 0.001002 [    0]/60000
# Loss: 0.000942 [12800]/60000
# Loss: 0.000926 [25600]/60000
# Loss: 0.000849 [38400]/60000
# Loss: 0.000891 [51200]/60000
#  > Training time: 4.99 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 57 out of 100
#  ------------
# Loss: 0.001072 [    0]/60000
# Loss: 0.000935 [12800]/60000
# Loss: 0.000940 [25600]/60000
# Loss: 0.000841 [38400]/60000
# Loss: 0.000857 [51200]/60000
#  > Training time: 4.80 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 58 out of 100
#  ------------
# Loss: 0.001077 [    0]/60000
# Loss: 0.000938 [12800]/60000
# Loss: 0.001006 [25600]/60000
# Loss: 0.000853 [38400]/60000
# Loss: 0.000880 [51200]/60000
#  > Training time: 4.86 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 59 out of 100
#  ------------
# Loss: 0.001070 [    0]/60000
# Loss: 0.000929 [12800]/60000
# Loss: 0.000984 [25600]/60000
# Loss: 0.000852 [38400]/60000
# Loss: 0.000861 [51200]/60000
#  > Training time: 5.02 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 60 out of 100
#  ------------
# Loss: 0.001049 [    0]/60000
# Loss: 0.000912 [12800]/60000
# Loss: 0.000945 [25600]/60000
# Loss: 0.000817 [38400]/60000
# Loss: 0.000833 [51200]/60000
#  > Training time: 4.93 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 61 out of 100
#  ------------
# Loss: 0.000998 [    0]/60000
# Loss: 0.000901 [12800]/60000
# Loss: 0.000940 [25600]/60000
# Loss: 0.000839 [38400]/60000
# Loss: 0.000828 [51200]/60000
#  > Training time: 4.86 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 62 out of 100
#  ------------
# Loss: 0.000965 [    0]/60000
# Loss: 0.000879 [12800]/60000
# Loss: 0.000939 [25600]/60000
# Loss: 0.000831 [38400]/60000
# Loss: 0.000818 [51200]/60000
#  > Training time: 4.92 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 63 out of 100
#  ------------
# Loss: 0.000994 [    0]/60000
# Loss: 0.000888 [12800]/60000
# Loss: 0.000920 [25600]/60000
# Loss: 0.000815 [38400]/60000
# Loss: 0.000831 [51200]/60000
#  > Training time: 4.96 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 64 out of 100
#  ------------
# Loss: 0.001048 [    0]/60000
# Loss: 0.000884 [12800]/60000
# Loss: 0.000922 [25600]/60000
# Loss: 0.000802 [38400]/60000
# Loss: 0.000832 [51200]/60000
#  > Training time: 4.98 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 65 out of 100
#  ------------
# Loss: 0.001033 [    0]/60000
# Loss: 0.000882 [12800]/60000
# Loss: 0.000928 [25600]/60000
# Loss: 0.000799 [38400]/60000
# Loss: 0.000802 [51200]/60000
#  > Training time: 4.86 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 66 out of 100
#  ------------
# Loss: 0.000978 [    0]/60000
# Loss: 0.000864 [12800]/60000
# Loss: 0.000903 [25600]/60000
# Loss: 0.000786 [38400]/60000
# Loss: 0.000787 [51200]/60000
#  > Training time: 4.88 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 67 out of 100
#  ------------
# Loss: 0.000984 [    0]/60000
# Loss: 0.000835 [12800]/60000
# Loss: 0.000848 [25600]/60000
# Loss: 0.000767 [38400]/60000
# Loss: 0.000779 [51200]/60000
#  > Training time: 4.94 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 68 out of 100
#  ------------
# Loss: 0.000983 [    0]/60000
# Loss: 0.000838 [12800]/60000
# Loss: 0.000861 [25600]/60000
# Loss: 0.000756 [38400]/60000
# Loss: 0.000776 [51200]/60000
#  > Training time: 4.92 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 69 out of 100
#  ------------
# Loss: 0.000959 [    0]/60000
# Loss: 0.000841 [12800]/60000
# Loss: 0.000869 [25600]/60000
# Loss: 0.000773 [38400]/60000
# Loss: 0.000794 [51200]/60000
#  > Training time: 4.97 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 70 out of 100
#  ------------
# Loss: 0.000995 [    0]/60000
# Loss: 0.000844 [12800]/60000
# Loss: 0.000869 [25600]/60000
# Loss: 0.000772 [38400]/60000
# Loss: 0.000781 [51200]/60000
#  > Training time: 5.11 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 71 out of 100
#  ------------
# Loss: 0.000939 [    0]/60000
# Loss: 0.000833 [12800]/60000
# Loss: 0.000862 [25600]/60000
# Loss: 0.000776 [38400]/60000
# Loss: 0.000782 [51200]/60000
#  > Training time: 5.17 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 72 out of 100
#  ------------
# Loss: 0.000948 [    0]/60000
# Loss: 0.000828 [12800]/60000
# Loss: 0.000857 [25600]/60000
# Loss: 0.000759 [38400]/60000
# Loss: 0.000768 [51200]/60000
#  > Training time: 5.02 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 73 out of 100
#  ------------
# Loss: 0.000967 [    0]/60000
# Loss: 0.000807 [12800]/60000
# Loss: 0.000835 [25600]/60000
# Loss: 0.000770 [38400]/60000
# Loss: 0.000760 [51200]/60000
#  > Training time: 4.91 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 74 out of 100
#  ------------
# Loss: 0.001001 [    0]/60000
# Loss: 0.000806 [12800]/60000
# Loss: 0.000833 [25600]/60000
# Loss: 0.000746 [38400]/60000
# Loss: 0.000746 [51200]/60000
#  > Training time: 4.98 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 75 out of 100
#  ------------
# Loss: 0.000987 [    0]/60000
# Loss: 0.000805 [12800]/60000
# Loss: 0.000818 [25600]/60000
# Loss: 0.000738 [38400]/60000
# Loss: 0.000735 [51200]/60000
#  > Training time: 5.10 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 76 out of 100
#  ------------
# Loss: 0.000931 [    0]/60000
# Loss: 0.000816 [12800]/60000
# Loss: 0.000838 [25600]/60000
# Loss: 0.000736 [38400]/60000
# Loss: 0.000731 [51200]/60000
#  > Training time: 5.00 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 77 out of 100
#  ------------
# Loss: 0.000918 [    0]/60000
# Loss: 0.000815 [12800]/60000
# Loss: 0.000832 [25600]/60000
# Loss: 0.000757 [38400]/60000
# Loss: 0.000773 [51200]/60000
#  > Training time: 5.04 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 78 out of 100
#  ------------
# Loss: 0.000924 [    0]/60000
# Loss: 0.000823 [12800]/60000
# Loss: 0.000803 [25600]/60000
# Loss: 0.000749 [38400]/60000
# Loss: 0.000758 [51200]/60000
#  > Training time: 4.99 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 79 out of 100
#  ------------
# Loss: 0.000964 [    0]/60000
# Loss: 0.000817 [12800]/60000
# Loss: 0.000823 [25600]/60000
# Loss: 0.000743 [38400]/60000
# Loss: 0.000766 [51200]/60000
#  > Training time: 4.94 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 80 out of 100
#  ------------
# Loss: 0.000902 [    0]/60000
# Loss: 0.000799 [12800]/60000
# Loss: 0.000823 [25600]/60000
# Loss: 0.000730 [38400]/60000
# Loss: 0.000749 [51200]/60000
#  > Training time: 4.88 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 81 out of 100
#  ------------
# Loss: 0.000963 [    0]/60000
# Loss: 0.000780 [12800]/60000
# Loss: 0.000830 [25600]/60000
# Loss: 0.000720 [38400]/60000
# Loss: 0.000740 [51200]/60000
#  > Training time: 4.84 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 82 out of 100
#  ------------
# Loss: 0.000885 [    0]/60000
# Loss: 0.000765 [12800]/60000
# Loss: 0.000808 [25600]/60000
# Loss: 0.000710 [38400]/60000
# Loss: 0.000716 [51200]/60000
#  > Training time: 4.86 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 83 out of 100
#  ------------
# Loss: 0.000898 [    0]/60000
# Loss: 0.000778 [12800]/60000
# Loss: 0.000840 [25600]/60000
# Loss: 0.000717 [38400]/60000
# Loss: 0.000737 [51200]/60000
#  > Training time: 4.76 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 84 out of 100
#  ------------
# Loss: 0.000859 [    0]/60000
# Loss: 0.000751 [12800]/60000
# Loss: 0.000798 [25600]/60000
# Loss: 0.000708 [38400]/60000
# Loss: 0.000720 [51200]/60000
#  > Training time: 5.03 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 85 out of 100
#  ------------
# Loss: 0.000858 [    0]/60000
# Loss: 0.000763 [12800]/60000
# Loss: 0.000787 [25600]/60000
# Loss: 0.000700 [38400]/60000
# Loss: 0.000727 [51200]/60000
#  > Training time: 5.11 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 86 out of 100
#  ------------
# Loss: 0.000836 [    0]/60000
# Loss: 0.000768 [12800]/60000
# Loss: 0.000776 [25600]/60000
# Loss: 0.000701 [38400]/60000
# Loss: 0.000735 [51200]/60000
#  > Training time: 5.26 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 87 out of 100
#  ------------
# Loss: 0.000956 [    0]/60000
# Loss: 0.000791 [12800]/60000
# Loss: 0.000766 [25600]/60000
# Loss: 0.000700 [38400]/60000
# Loss: 0.000740 [51200]/60000
#  > Training time: 5.06 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 88 out of 100
#  ------------
# Loss: 0.000868 [    0]/60000
# Loss: 0.000771 [12800]/60000
# Loss: 0.000784 [25600]/60000
# Loss: 0.000681 [38400]/60000
# Loss: 0.000751 [51200]/60000
#  > Training time: 5.02 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 89 out of 100
#  ------------
# Loss: 0.000892 [    0]/60000
# Loss: 0.000762 [12800]/60000
# Loss: 0.000766 [25600]/60000
# Loss: 0.000688 [38400]/60000
# Loss: 0.000732 [51200]/60000
#  > Training time: 4.95 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 90 out of 100
#  ------------
# Loss: 0.000856 [    0]/60000
# Loss: 0.000765 [12800]/60000
# Loss: 0.000744 [25600]/60000
# Loss: 0.000675 [38400]/60000
# Loss: 0.000712 [51200]/60000
#  > Training time: 5.03 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 91 out of 100
#  ------------
# Loss: 0.000836 [    0]/60000
# Loss: 0.000745 [12800]/60000
# Loss: 0.000754 [25600]/60000
# Loss: 0.000678 [38400]/60000
# Loss: 0.000706 [51200]/60000
#  > Training time: 5.13 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 92 out of 100
#  ------------
# Loss: 0.000848 [    0]/60000
# Loss: 0.000751 [12800]/60000
# Loss: 0.000752 [25600]/60000
# Loss: 0.000676 [38400]/60000
# Loss: 0.000702 [51200]/60000
#  > Training time: 5.11 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 93 out of 100
#  ------------
# Loss: 0.000849 [    0]/60000
# Loss: 0.000748 [12800]/60000
# Loss: 0.000749 [25600]/60000
# Loss: 0.000667 [38400]/60000
# Loss: 0.000696 [51200]/60000
#  > Training time: 4.91 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 94 out of 100
#  ------------
# Loss: 0.000832 [    0]/60000
# Loss: 0.000751 [12800]/60000
# Loss: 0.000760 [25600]/60000
# Loss: 0.000659 [38400]/60000
# Loss: 0.000703 [51200]/60000
#  > Training time: 4.93 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 95 out of 100
#  ------------
# Loss: 0.000834 [    0]/60000
# Loss: 0.000739 [12800]/60000
# Loss: 0.000758 [25600]/60000
# Loss: 0.000678 [38400]/60000
# Loss: 0.000706 [51200]/60000
#  > Training time: 4.95 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 96 out of 100
#  ------------
# Loss: 0.000815 [    0]/60000
# Loss: 0.000742 [12800]/60000
# Loss: 0.000752 [25600]/60000
# Loss: 0.000679 [38400]/60000
# Loss: 0.000707 [51200]/60000
#  > Training time: 5.05 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 97 out of 100
#  ------------
# Loss: 0.000858 [    0]/60000
# Loss: 0.000732 [12800]/60000
# Loss: 0.000725 [25600]/60000
# Loss: 0.000677 [38400]/60000
# Loss: 0.000719 [51200]/60000
#  > Training time: 4.97 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 98 out of 100
#  ------------
# Loss: 0.000840 [    0]/60000
# Loss: 0.000745 [12800]/60000
# Loss: 0.000739 [25600]/60000
# Loss: 0.000676 [38400]/60000
# Loss: 0.000732 [51200]/60000
#  > Training time: 4.97 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 99 out of 100
#  ------------
# Loss: 0.000823 [    0]/60000
# Loss: 0.000755 [12800]/60000
# Loss: 0.000726 [25600]/60000
# Loss: 0.000666 [38400]/60000
# Loss: 0.000705 [51200]/60000
#  > Training time: 4.91 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Epoch 100 out of 100
#  ------------
# Loss: 0.000826 [    0]/60000
# Loss: 0.000741 [12800]/60000
# Loss: 0.000736 [25600]/60000
# Loss: 0.000666 [38400]/60000
# Loss: 0.000702 [51200]/60000
#  > Training time: 5.21 seconds
#  > Test reconstruction loss: 0.00
# Model ./models\uns_ae_mnist.pth stored!
# Done!
